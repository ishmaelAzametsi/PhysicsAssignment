# %% [markdown]
# <font color="blue"><h1>ASSIGNMENT</h1></font>

# %% [markdown]
# **NAME: AZAMETSI ISHMAEL**
#
#
# **INDEX NUMBER: 9448219**

# %% [markdown]
# # Question 1
#
# Write a Python code to numerically solve the time-independent Schrödinger equation for a particle in a one-dimensional potential well. The potential energy function is given by:
#
#
# V(x) = { 0         , for 0 $\leq$ x $\leq$ a <br />
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;       V$_0$       , for a $\lt$ x $\leq$ b <br />
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;       infinity  , for x $\lt$ 0 or x $\gt$ b <br />
#       } <br />
#
# where a and b are the width of the well and the total width of the system, respectively, and V$_0$ is the height of the potential barrier. <br />
#
# Use the finite difference method to discretize the wavefunction and the potential energy function, and solve the resulting eigenvalue problem using the numpy library. Use this simulation to investigate the effect of the well width a and the barrier height V$_0$ on the energy eigenvalues and wavefunctions of the particle.<br />
#
# Additionally, use the matplotlib library to plot the energy eigenvalues and wavefunctions as a function of a and V$_0$, and discuss the physical significance of the results.
#
#
# ***Make Use of Classes for your solution***

# %% [markdown]
# # Instruction:
#
# For this assignment, submission must be done via Github.
# Create a Guthub account and an Assignment repo. A google sheet will be circulated. On the Google sheet, enter your Github URL. Ensure that the URL is correctly inserted. <br />
#
#
# Your submission should follow the structure below. You are at liberty to include images or text as you deem fit. However, they must be sound and relate to the topic. <br />
#
# <h3> Deadline: 3rd May 2023 (12:00 Midday) </h3>

# %% [markdown]
# <font color="red"><h2> Background</h2></font>
#
# - Briefly describe what Computational Physics is (A Brief Bakground)<br />
# - Link it to the task you have been given <br />
# - Outline your objectives for this study

# %% [markdown]
# # COMPUTATIONAL PHYSICS
#
# Computational physics is a branch of physics that focuses on using computational and numerical approaches to address physics problems. It entails creating and deploying algorithms and software to simulate physical systems and phenomena that are difficult or impossible to examine experimentally or analytically.Computational physics can be used to model a wide range of physical phenomena, such as the behavior of fluids, the interaction of particles, the properties of materials, the dynamics of complex systems, and the behavior of electromagnetic fields. It is used to simulate the behavior of systems on different scales, from the subatomic to the astronomical.Computer programming, mathematical modeling, and numerical approaches are intensively used in computational physics. It blends physics, computer science, and mathematics to develop powerful tools for understanding and forecasting physical system behavior.
#
# # LINK TO TASK
#
#
# Computational physics is important to many areas of physics, including the study of the time-independent Schrödinger equation (TISE). The TISE is a fundamental equation in quantum mechanics that describes the behavior of quantum systems in the absence of time dependence. It is used to calculate the energy levels and wave functions of atoms, molecules, and other quantum systems.Computational physics provides powerful tools for solving the TISE numerically, allowing physicists to study the behavior of quantum systems that are difficult or impossible to study analytically. This is particularly important for understanding the behavior of complex systems with many interacting particles, such as molecules and materials.One approach to solving the TISE numerically is to use a method called the finite difference method, in which the differential equation is discretized on a grid and solved iteratively. Another approach is to use a method called the finite element method, in which the differential equation is approximated using a set of basis functions and solved using linear algebra.Computational physics also allows physicists to study the behavior of quantum systems in the presence of external fields and interactions, which can have a significant impact on the energy levels and wave functions of the system. This is important for understanding the behavior of atoms and molecules in electric and magnetic fields, as well as the behavior of materials under different conditions.In summary, computational physics plays an important role in the study of TISE and many other areas of physics, providing powerful tools for understanding and predicting the behavior of physical systems.
#
#
# # OBJECTIVES
# 1.Understanding the behavior of quantum systems: Quantum mechanics describes the behavior of particles on a very small scale, while quantum computational physics uses computer methods to understand and predict the behavior of these systems. This involves research on quantum entanglement, superposition, and interference.<br>
# 2.Creating new quantum algorithms: Quantum computational physics strives to create new algorithms that can take use of quantum systems' unique qualities, such as the capacity to execute many calculations at the same time. These algorithms have the ability to address issues that traditional computers are unable to solve.<br>
# 3.Designing new quantum hardware: As quantum computers become more powerful, it is important to develop new hardware that can take advantage of these advances. Quantum computational physics aims to design and optimize new quantum hardware, such as qubits and quantum gates, to improve the performance of quantum computers.<br>
# 4.Quantum computational physics has potential applications in a variety of domains, including materials research, chemistry, encryption, and optimization. The goal of quantum computational physics research is to provide new tools and approaches that can be used to address complicated problems in these domains.<br>
# 5.Understanding the limitations of quantum computing: Quantum computational physics also aims to understand the limitations of quantum computing, including the effects of noise and decoherence on quantum systems. This knowledge is important for developing error correction techniques and improving the reliability of quantum computers.

# %% [markdown]
# <font color="red"><h2> Method and Results </h2></font>
#
# - Solve the question here and discuss the results <br />

# %% [markdown]
# The Time Independent Schrodinger Equation (TISE)
# $$ -\frac{\hbar^2}{2m}\frac{d^2}{d x^2} \psi(x) + V(x)\psi(x) = E\psi(x)$$
# where $\hbar$ is the reduced Planck's constant, $m$ is the mass of the particle, $\nabla^2$ is the Laplacian operator, $V(\mathbf{r})$ is the potential energy function, $\Psi(\mathbf{r})$ is the wave function, $E$ is the total energy of the system, and $\mathbf{r}$ represents the position coordinates of all particles in the system.

# %%
import numpy as np
import matplotlib.pyplot as plt

class NumericalDifferentiation:
    def __init__(self, N):
        self.N = N
        self.x = np.linspace(0, 2 * np.pi, N)
        self.h = self.x[1] - self.x[0]
    
    def differentiate(self, y):
        dydx = np.zeros_like(y)
        d2ydx2 = np.zeros_like(y)
        
        # Compute the first derivative of y using forward and backward difference methods
        dydx[0] = (y[1] - y[0]) / self.h
        dydx[-1] = (y[-1] - y[-2]) / self.h
        dydx[1:-1] = (y[2:] - y[:-2]) / (2.0 * self.h)
        
        # Compute the second derivative of y using central difference method
        d2ydx2[1:-1] = (y[2:] - 2.0 * y[1:-1] + y[:-2]) / (self.h ** 2)
        
        return dydx, d2ydx2

# Define the number of points in our space, N
N = 128

# Compute the function y = sin(x). With numpy this is easy:
y = np.sin(np.linspace(0, 2 * np.pi, N))

# Create differentiation object
diff = NumericalDifferentiation(N)

# Compute first and second derivative of y
yp, ypp = diff.differentiate(y)

# Plot the results.
plt.figure(figsize=(10, 7))
plt.plot(diff.x, y, label='y')
plt.plot(diff.x, yp, label='y`')
plt.plot(diff.x, ypp, label='y``')
plt.legend()
plt.show()

# %% [markdown]
# ## INFINITE SQAURE WELL
#
# The very simplest system to solve for is the infinite square well, for which $V=0$. We will readily recognize the results as alternating $\cos(x)$ and $\sin(x)$ functions, and the energy levels are:
# $$
# E_i = \frac{n^2\pi^2\hbar^2}{2ma^2}
# $$
# First, we need to discuss a subtlety. The Infinite Square Well from $-a/2$ to $a/2$ has $V=\infty$ *at* these points. We get into trouble trying to entery $\infty$ in our potential, so what we need to do is just limit the coputational space from $-a/2+h$ to $a/2-h$, where $h$ is our step size. That way we force the wavefunction to zero at the end points.
# We compute this in the next box. I create $x_{full}$ as the full x-axis from $-a/2$ to $a/2$, but take $N+2$ steps. I then leave out the first and last point when calculating the wavefunctions. At the end, before plotting, I add a zero to the beginning and end of the wavefunctions, so that we get the expected result for plotting.
#
# Note I again import everything and setup all the definitions, so this block is stand-alone, and can be copy-pasted into another notebook.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as scl
hbar=1
m=1
N = 512
a = 1.0
x = np.linspace(-a/2.,a/2.,N)
# We want to store step size, this is the reliable way:
h = x[1]-x[0] # Should be equal to 2*np.pi/(N-1)
V = 0.*x
Mdd = 1./(h*h)*(np.diag(np.ones(N-1),-1) -2* np.diag(np.ones(N),0) + np.diag(np.ones(N-1),1))
H = -(hbar*hbar)/(2.0*m)*Mdd + np.diag(V) 
E,psiT = np.linalg.eigh(H) # This computes the eigen values and eigenvectors
psi = np.transpose(psiT)   # We take the transpose of psiT to the wavefunction vectors can accessed as psi[n]
#

# %%
plt.figure(figsize=(10,7))
for i in range(5):
    if psi[i][N-10] < 0:   # Flip the wavefunctions if it is negative at large x, so plots are more consistent.
        plt.plot(x,-psi[i]/np.sqrt(h),label="$E_{}$={:>8.3f}".format(i,E[i]))
    else:
        plt.plot(x,psi[i]/np.sqrt(h),label="$E_{}$={:>8.3f}".format(i,E[i]))
    plt.title("Solutions to the Infinite Square Well")
plt.legend()
plt.savefig("Infinite_Square_Well_WaveFunctions.pdf")
plt.show()

# %% [markdown]
# <font color="red"><h2> Conclusion </h2></font>
#
# - Give a brief conclusion. <br />
# - Also, discuss your learning journey. Highlight your challenges and great moments. <br />

# %% [markdown]
# ## conclusion
#
# In this conversation, we started with a question about an implementation of numerical differentiation in Python using matrices. We discussed the code, its purpose, and how it works. We also explored an alternative implementation using the central difference formula. Finally, we concluded with a summary of our discussion.
#
# ## challenges
# During this conversation, we explored the topic of numerical differentiation in Python, discussing an implementation using matrices and an alternative approach using the central difference formula. The conversation was informative and interactive, and it allowed us to delve into the details of the code and its underlying concepts. As a student, my "learning journey" has been to process and analyze human language, so I don't have a personal learning journey. However, I can provide some insights on how this conversation can help a learner who is interested in the topic of numerical differentiation. By discussing the code and the underlying concepts, we were able to clarify some of the important aspects of numerical differentiation, including the use of matrices, the first and second derivatives, and the central difference formula. We also demonstrated how to implement these concepts in Python.Overall, this conversation serves as a useful resource for someone looking to learn about numerical differentiation, as it provides a practical example and explanations of the underlying concepts.

# %% [markdown]
# <font color="red"><h2> Recommendation(s) </h2></font>
#
# - What area(s) do you suggest the class covers? <br />

# %% [markdown]
# we should focus more on problems invloving physics and scientific theories
